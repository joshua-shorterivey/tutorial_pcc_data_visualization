# %% [markdown]
# 17-1. Other Languages: Modify the API call in python_repos.py so it generates a chart showing the most popular projects in other languages. Try languages such as JavaScript, Ruby, C, Java, Perl, Haskell, and Go.

# %%
import requests

#make an api cal and store the response
url = "https://api.github.com/search/repositories?q=langauge:java&sort=stars"
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

#store api response in a variable.
response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")

#explore information about the repositories
repo_dicts = response_dict['items']
print((f"Repositories returned: {len(repo_dicts)}"))

#printing selected info for certain keys
print("\nSelected information about each repository:")
for repo_dict in repo_dicts:
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
    print(f"Description: {repo_dict['description']}")
# Out:
# Status code: 200
# Total repositories: 62
# Repositories returned: 30
#
# Selected information about each repository:
# Name: th4j
# Owner: ET-Chan
# Stars: 11
# Repository: https://github.com/ET-Chan/th4j
# Created: 2015-10-06T22:45:00Z
# Updated: 2018-09-29T22:32:55Z
# Description: TH4J- A wrapper of torch TH library for Java (JVM langauges).
# Name: Hackerrank-Solutions
# Owner: AyushPradhan9
# Stars: 7
# Repository: https://github.com/AyushPradhan9/Hackerrank-Solutions
# Created: 2020-03-31T09:29:13Z
# Updated: 2023-01-25T14:48:04Z
# Description: Hackerrank solutions to C++ / Java / C Langauge / Problem Solving / Python
# Name: Projects
# Owner: abhi9720
# Stars: 3
# Repository: https://github.com/abhi9720/Projects
# Created: 2020-11-29T10:30:15Z
# Updated: 2022-06-26T16:34:24Z
# Description: Build some simple projects in Java , Python and C language to learn basics of langauge in more better way .
# Name: projects
# Owner: Jorge-D-Robles
# Stars: 2
# Repository: https://github.com/Jorge-D-Robles/projects
# Created: 2022-10-30T18:38:26Z
# Updated: 2022-11-04T21:21:24Z
# Description: Portfolio-quality projects using various langauges such as Python, HTML, CSS, Java, JavaScript, etc.
# Name: RANDOM_DATA
# Owner: ParfaitG
# Stars: 2
# Repository: https://github.com/ParfaitG/RANDOM_DATA
# Created: 2017-09-23T16:11:03Z
# Updated: 2020-07-14T23:42:00Z
# Description: Scripts to generate random data across various data types (int, character, numeric, boolean, date) and langauges (Java, PHP, Python, R, SQL, SAS, VBA)
# Name: Scanner_Compiler_Java
# Owner: Asad-Chuadhry
# Stars: 1
# Repository: https://github.com/Asad-Chuadhry/Scanner_Compiler_Java
# Created: 2020-02-22T04:25:20Z
# Updated: 2022-10-31T18:31:34Z
# Description: A java program to implement scanner(first part of compiler) for java langauge
# Name: java-dsa
# Owner: AliFahed
# Stars: 1
# Repository: https://github.com/AliFahed/java-dsa
# Created: 2022-08-21T17:00:51Z
# Updated: 2022-09-03T14:26:09Z
# Description: This repo contains exercises to learn data structures and algorithms using java programming langauge.
# Name: ADS-Project
# Owner: KrishTheDuck
# Stars: 1
# Repository: https://github.com/KrishTheDuck/ADS-Project
# Created: 2021-05-07T16:16:04Z
# Updated: 2021-11-06T18:56:53Z
# Description: Langauge with a compiler written purely in Java (because why not)
# Name: 30-Days-of-code
# Owner: NimeshBhavsar
# Stars: 1
# Repository: https://github.com/NimeshBhavsar/30-Days-of-code
# Created: 2021-08-14T13:24:50Z
# Updated: 2023-01-11T10:25:39Z
# Description: This Repository contains all the solutions of Hackerrank Course "30 Days of Code" in Java as well as C langauge
# Name: messaging-App-using-jee-Postfix
# Owner: Mohamed-El-amri2000
# Stars: 1
# Repository: https://github.com/Mohamed-El-amri2000/messaging-App-using-jee-Postfix
# Created: 2022-09-04T20:22:06Z
# Updated: 2022-09-24T12:55:14Z
# Description: application de messagerie electronique gérer par le serveur de messagrie postfix qui est installer  sous linux ,cette application a été développé par langauge java ee
# Name: UnoCardGame_App
# Owner: BriannaChou
# Stars: 1
# Repository: https://github.com/BriannaChou/UnoCardGame_App
# Created: 2021-03-21T20:34:21Z
# Updated: 2021-04-29T00:55:48Z
# Description: Team members: Brianna Chou, Adeline Azungue, JT Emnett, Alexis Flores  We are programming an application that will allow a user to play Uno Card game against a computer.  Langauge: Java  IDE: Apache Net Bean 11.3
# Name: Note-Taking-Android-App-Project
# Owner: shubhdhungana
# Stars: 1
# Repository: https://github.com/shubhdhungana/Note-Taking-Android-App-Project
# Created: 2022-12-24T15:34:48Z
# Updated: 2022-12-24T16:12:42Z
# Description: This was the note taking android app project done by me. It was built using java programming langauge. It was built via Android Studio. It was really fun to do such android app project.
# Name: Java
# Owner: AbdulNasir-NuZ
# Stars: 0
# Repository: https://github.com/AbdulNasir-NuZ/Java
# Created: 2022-10-02T09:15:04Z
# Updated: 2022-10-02T09:20:51Z
# Description: Java Programming langauge Documentary
# Name: Java-Interpreter
# Owner: jasky1640
# Stars: 0
# Repository: https://github.com/jasky1640/Java-Interpreter
# Created: 2019-06-20T07:08:16Z
# Updated: 2021-02-07T21:42:00Z
# Description: Java(ish) Langauge Interpreter
# Name: data-structure-java
# Owner: AishwaryaJorve
# Stars: 0
# Repository: https://github.com/AishwaryaJorve/data-structure-java
# Created: 2021-08-15T17:18:12Z
# Updated: 2022-02-23T17:50:26Z
# Description: Data structure in java langauge
# Name: JavaProgramming
# Owner: Harin3Bone
# Stars: 0
# Repository: https://github.com/Harin3Bone/JavaProgramming
# Created: 2020-12-30T04:10:05Z
# Updated: 2021-11-14T15:59:07Z
# Description: Project for training java programming langauge
# Name: javaBasic
# Owner: viveknapit
# Stars: 0
# Repository: https://github.com/viveknapit/javaBasic
# Created: 2021-12-15T14:39:47Z
# Updated: 2021-12-15T14:42:37Z
# Description: learn basic concepts of java programming langauge
# Name: Viewstudent
# Owner: adamrogo
# Stars: 0
# Repository: https://github.com/adamrogo/Viewstudent
# Created: 2017-11-18T21:27:49Z
# Updated: 2017-11-26T22:18:10Z
# Description: To view student using java programming langauge
# Name: TicTacToe_Using_Java
# Owner: edujbarrios
# Stars: 0
# Repository: https://github.com/edujbarrios/TicTacToe_Using_Java
# Created: 2022-12-24T13:38:55Z
# Updated: 2022-12-24T13:40:16Z
# Description: TicTacToe implementation using Java programming langauge
# Name: dikshaproject
# Owner: diksha301
# Stars: 0
# Repository: https://github.com/diksha301/dikshaproject
# Created: 2022-10-18T10:09:19Z
# Updated: 2022-10-18T10:09:19Z
# Description: i make website in java langauge
# Name: Tic-Tac-Toe
# Owner: rs8429080702
# Stars: 0
# Repository: https://github.com/rs8429080702/Tic-Tac-Toe
# Created: 2023-01-09T17:41:42Z
# Updated: 2023-01-09T17:54:26Z
# Description: This game is made by using java langauge
# Name: tptp-java-parser
# Owner: xu-hao
# Stars: 0
# Repository: https://github.com/xu-hao/tptp-java-parser
# Created: 2013-05-18T17:46:17Z
# Updated: 2013-12-06T07:39:57Z
# Description: A Java parser for a subset of the TPTP langauge
# Name: BlueRaspberry
# Owner: DJLW78nRAX
# Stars: 0
# Repository: https://github.com/DJLW78nRAX/BlueRaspberry
# Created: 2018-02-15T00:38:09Z
# Updated: 2018-02-15T00:38:09Z
# Description: A programming langauge constructed in java, open source.
# Name: problem-solving-with-java
# Owner: mightykim91
# Stars: 0
# Repository: https://github.com/mightykim91/problem-solving-with-java
# Created: 2020-09-17T17:15:28Z
# Updated: 2020-09-17T17:37:14Z
# Description: This repository contains code for problem solving with java langauge
# Name: Graphics-to-Artifical-Intelligence
# Owner: GobalKrishnan
# Stars: 0
# Repository: https://github.com/GobalKrishnan/Graphics-to-Artifical-Intelligence
# Created: 2019-05-17T13:16:39Z
# Updated: 2019-07-31T05:50:57Z
# Description: To create Artifical Intelligence,Base programming langauge is java
# Name: java_projects
# Owner: rizsim214
# Stars: 0
# Repository: https://github.com/rizsim214/java_projects
# Created: 2022-04-07T12:37:31Z
# Updated: 2022-04-07T12:39:56Z
# Description: Project Repo for Java Programming Langauge for NexSeed
# Name: addstudent-with-java
# Owner: adamrogo
# Stars: 0
# Repository: https://github.com/adamrogo/addstudent-with-java
# Created: 2017-11-18T21:19:26Z
# Updated: 2017-11-18T21:19:26Z
# Description: Class to add student using java programming langauge
# Name: JavaTutorials
# Owner: himanshuit007
# Stars: 0
# Repository: https://github.com/himanshuit007/JavaTutorials
# Created: 2015-12-11T17:29:31Z
# Updated: 2020-02-24T05:26:01Z
# Description: Tutorials on various topics of Java programming langauge
# Name: VigProgrammingLanguage
# Owner: Flaymed
# Stars: 0
# Repository: https://github.com/Flaymed/VigProgrammingLanguage
# Created: 2020-02-13T01:03:02Z
# Updated: 2020-02-21T01:16:09Z
# Description: Python, Java, and JavaScript syntax combined into a new type of programming langauge. Vig. (.v extension)
# Name: Java-Programs
# Owner: ramizaly
# Stars: 0
# Repository: https://github.com/ramizaly/Java-Programs
# Created: 2022-09-19T17:46:17Z
# Updated: 2022-09-19T17:47:28Z
# Description: This repo contains CLI level programs using Java as a programming langauge.

# %% [markdown]
# 17-2. Active Discussions: Using the data from hn_submissions.py, make a bar chart showing the most active discussions currently happening on Hacker News. The height of each bar should correspond to the number of comments each submission has. The label for each bar should include the submission’s title and should act as a link to the discussion page for that submission.

# %% [markdown]
# 17-3. Testing python_repos.py: In python_repos.py, we printed the value of status_code to make sure the API call was successful. Write a program called test_python_repos.py that uses unittest to assert that the value of status_code is 200. Figure out some other assertions you can make—for example, that the number of items returned is expected and that the total number of repositories is greater than a certain amount.

# %% [markdown]
# 17-4. Further Exploration: Visit the documentation for Plotly and either the GitHub API or the Hacker News API. Use some of the information you find there to either customize the style of the plots we’ve already made or pull some different information and create your own visualizations.
